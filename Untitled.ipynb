# %%
from pandas import read_csv
# %matplotlib inline

# %%
fn0 = 'SIXcsv/SXitd_SPICHA_2016-11-09_163212.csv'
fn1 = 'SIXcsv/SXitd_SPI_2016-11-09_163212.csv'
fn2 = 'SIXcsv/SXitd_CHSPI_2016-11-09_163212.csv'

# %%
etf1 = read_csv(fn0, encoding='latin1', delimiter=';', skiprows=2, usecols=[0,1,2])
spi = read_csv(fn1, encoding='latin1', delimiter=';', skiprows=2, usecols=[0,1,2])
etf2 = read_csv(fn2, encoding='latin1', delimiter=';', skiprows=2, usecols=[0,1,2])

# %%
etf1.Price.plot(figsize=(10,2))

# %%
etf2.Price.plot(figsize=(10,2))

# %%
spi.Price.plot(figsize=(10,2))
