# %% [markdown]
# ## read all SIX csv files and create pandas datafram

# %%
from pandas import read_csv, MultiIndex, concat, read_excel
from collections import namedtuple
from datetime import time,datetime
import matplotlib.pyplot as plt
import codecs
import os

# %matplotlib inline

# %%
def get_pfad():
    '''
    returns path for different files as needed per PC
    '''

    Context = namedtuple('contexts', 'pfadKGAST, pfadSIX')
    pfade = ['c:/users/gfi 64bit/',
             'c:/users/gerar/',
             'c:/users/gérard/']
    try:
        pfad = [pfad for pfad in pfade if os.path.exists(pfad)][0]
    except:
        pfad = ''
        raise FileNotFoundError('Zuerst gültigen Pfad definieren!')
    pfad += 'dropbox/KGAST Daten/'
    context = Context(pfad + 'KGASTxls/', pfad + 'SIXcsv/')
    return context

def get_itd(filename):
    ''' read intraday csv file and return a dataframe with:
    MultiIndex : Name = name of index, datetime 
    Price, Volume '''
    # read header information
    with codecs.open(filename, encoding='latin', errors='replace') as myfile:
        ind_name, datum = myfile.readlines()[:2]
    ind_name =ind_name.strip('\r\n').replace(u'\xa0', u' ')
    datum = datum.strip().strip(';')
    tag, monat, jahr = datum.strip().strip(';').split('.')
    # read price data
    df = read_csv(p.pfadSIX+fname, sep=';', skiprows=2, usecols=[0, 1, 2])
    df.columns = [col.strip() for col in df.columns.tolist()]
    x = lambda zeit : datetime(int(jahr), int(monat), int(tag), int(zeit[-8:-6]), int(zeit[-5:-3]), int(zeit[-2:]))
    # create new columns for indexing and set multiindex
    df['Time'] = df.Time.map(x)
    df['Name'] = ind_name
    return df.set_index(['Time'])

# %%
p = get_pfad()
print(p.pfadKGAST, ' -- ',p.pfadKGAST)
fnames = os.listdir(p.pfadKGAST)
fnames =[fname for fname in fnames if 'KGAST' in fname] # keep intraday
print(fnames[1])
# Out:
# c:/users/gfi 64bit/dropbox/KGAST Daten/KGASTxls/  --  c:/users/gfi 64bit/dropbox/KGAST Daten/KGASTxls/
# KGAST2016-10-14--143055.xls

# %%
fn = p.pfadKGAST + fnames[0]
print(len(fnames), fn)
a = read_excel(fn)
a.info(verbose=False)
# Out:
# 459 c:/users/gfi 64bit/dropbox/KGAST Daten/KGASTxls/KGAST2016-10-14--142833.xls
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Columns: 12 entries, MITGLIEDER to AENDERUNGSDAT
# dtypes: object(12)
# memory usage: 41.6+ KB

# %%
flist = []
for fn in fnames:
    flist.append(read_excel(p.pfadKGAST + fn))

# %%
df = concat(flist)
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201233 entries, 0 to 437
# Columns: 12 entries, MITGLIEDER to AENDERUNGSDAT
# dtypes: object(12)
# memory usage: 20.0+ MB

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29011 entries, 0 to 436
# Data columns (total 12 columns):
# MITGLIEDER         29011 non-null object
# KURZ               29011 non-null object
# BESCHREIBUNG       1208 non-null object
# VALOR              29011 non-null object
# ANLAGEGRUPPE       29011 non-null object
# AUSGABEPREIS       28891 non-null object
# RUECKNAHMEPREIS    28996 non-null object
# AUFGEL_ERTRAG      28975 non-null object
# EINGABESCHLUSS     28977 non-null object
# ABSCHLUSSTAG       29001 non-null object
# VALUTA             26117 non-null object
# AENDERUNGSDAT      28994 non-null object
# dtypes: object(12)
# memory usage: 2.9+ MB

# %%
df
# Out:
#                                             MITGLIEDER                KURZ  \
# 0    Anlagestiftung der UBS für Personalvorsorge / ...                 UBS
# 1                                Zürich Anlagestiftung              Zürich
# 2    Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 3                      J. Safra Sarasin Anlagestiftung                SAST
# 4                      J. Safra Sarasin Anlagestiftung                SAST
# 5                                PRISMA Anlagestiftung              PRISMA
# 6    Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 7    Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 8    Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 9                  ASSETIMMO Immobilien-Anlagestiftung           assetimmo
# 10                 ASSETIMMO Immobilien-Anlagestiftung           assetimmo
# 11                           Anlagestiftung Swiss Life          Swiss Life
# 12   Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 13   Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 14   Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 15   Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 16                               Zürich Anlagestiftung              Zürich
# 17         IST Investmentstiftung für Personalvorsorge                 IST
# 18         IST Investmentstiftung für Personalvorsorge                 IST
# 19   Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 20   Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 21     Avadis Anlagestiftung / Avadis Anlagestiftung 2  Avadis AST / AST 2
# 22                          Patrimonium Anlagestiftung         Patrimonium
# 23   Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 24   Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 25   Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 26   Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 27   Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 28   Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 29   Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# ..                                                 ...                 ...
# 390                             IST Investmentstiftung                 IST
# 391                             IST Investmentstiftung                 IST
# 392  Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 393                             IST Investmentstiftung                 IST
# 394                             IST Investmentstiftung                 IST
# 395                             IST Investmentstiftung                 IST
# 399                          Anlagestiftung Winterthur                 AWi
# 400                    J. Safra Sarasin Anlagestiftung                SAST
# 401  Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 402  Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 403  Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 404                    J. Safra Sarasin Anlagestiftung                SAST
# 405  Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 414  Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 416        Bâloise-Anlagestiftung für Personalvorsorge             Bâloise
# 417        Bâloise-Anlagestiftung für Personalvorsorge             Bâloise
# 418        Bâloise-Anlagestiftung für Personalvorsorge             Bâloise
# 419  Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 420  Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 421  Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 422  Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 423  Credit Suisse Anlagestiftung / Credit Suisse A...         CSA / CSA 2
# 424                          Anlagestiftung Winterthur                 AWi
# 425                          Anlagestiftung Winterthur                 AWi
# 426                          Anlagestiftung Winterthur                 AWi
# 432  Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 433  Swisscanto Anlagestiftung / Swisscanto Anlages...          Swisscanto
# 434                             IST Investmentstiftung                 IST
# 435                    J. Safra Sarasin Anlagestiftung                SAST
# 436                    J. Safra Sarasin Anlagestiftung                SAST
#
#                                           BESCHREIBUNG      VALOR  \
# 0                                                  NaN   10077053
# 1    <p>&Auml;nderungsdatum = Handelstag<br />Absch...    1011761
# 2                                                  NaN   10157421
# 3                                                  NaN    1016859
# 4                                                  NaN    1016862
# 5                                                  NaN   10197144
# 6                                                  NaN   10382676
# 7                                                  NaN    1039194
# 8                                                  NaN   10399033
# 9    <p><span style="color: #000000;"><strong>Hinwe...    1049345
# 10   <p><span style="color: #000000;"><strong>Hinwe...    1049349
# 11                                                 NaN   10615013
# 12                                                 NaN    1062835
# 13                                                 NaN   10733071
# 14                                                 NaN   10734846
# 15                                                 NaN    1082332
# 16   <p>&Auml;nderungsdatum = Handelstag<br />Absch...    1085303
# 17                                                 NaN  109644920
# 18                                                 NaN  109645610
# 19                                                 NaN   11177570
# 20                                                 NaN   11217285
# 21   <p>Aufgel_ertrag=Performance YTD</p>\r\n<p>Ein...    1121984
# 22                                                 NaN   11258967
# 23                                                 NaN   11269573
# 24                                                 NaN   11269640
# 25                                                 NaN    1131586
# 26                                                 NaN    1131588
# 27                                                 NaN    1131589
# 28                                                 NaN    1131590
# 29                                                 NaN    1131591
# ..                                                 ...        ...
# 390                                                NaN   44935670
# 391                                                NaN   44935750
# 392                                                NaN    4541793
# 393                                                NaN    4569920
# 394                                                NaN    4569930
# 395                                                NaN    4569940
# 399  <ul>\r\n<li><strong>Eingabeschluss:&nbsp;</str...    4735240
# 400                                                NaN    4955026
# 401                                                NaN     511136
# 402                                                NaN     511138
# 403                                                NaN     511147
# 404                                                NaN     656054
# 405                                                NaN     694458
# 414                                                NaN     788833
# 416                                                NaN     835628
# 417                                                NaN     835654
# 418                                                NaN     835655
# 419                                                NaN     887902
# 420                                                NaN     887904
# 421                                                NaN     887909
# 422                                                NaN     887912
# 423                                                NaN     888066
# 424  <ul>\r\n<li><strong>Eingabeschluss:&nbsp;</str...     900434
# 425  <ul>\r\n<li><strong>Eingabeschluss:&nbsp;</str...     900450
# 426  <ul>\r\n<li><strong>Eingabeschluss:&nbsp;</str...     900453
# 432                                                NaN     947743
# 433                                                NaN     947744
# 434                                                NaN     967000
# 435                                                NaN     978277
# 436                                                NaN     978280
#
#                                    ANLAGEGRUPPE AUSGABEPREIS RUECKNAHMEPREIS  \
# 0       UBS AST Kommerzielle Immobilien Schweiz      1512.67         1472.09
# 1                                  Aktien Japan       744.37          742.14
# 2              CSA Insurance Linked Stategies L      1431.01         1431.01
# 3                                   BVG-Rendite         1385            1385
# 4                            BVG-Nachhaltigkeit         1404            1404
# 5                  PRISMA Risk Budgeting Line 5     1'113.17        1'113.17
# 6                        CSA Mixta-BVG Index 45      1410.98         1407.18
# 7        CSA Equity Small & Mid Cap Switzerland      2218.02         2218.02
# 8                       CSA Global Bonds Hedged      1200.92         1200.92
# 9           Anlagegruppe W (Wohnliegenschaften)       533.54          507.52
# 10     Anlagegruppe G (Geschäftsliegenschaften)       426.71          405.89
# 11                           Immobilien Schweiz       147.07          147.07
# 12   CSA Fund Selection Equity Emerging Markets      1237.06         1237.06
# 13        CSA Fund Selection Equity Switzerland      1598.71         1598.71
# 14      CSA Fund Selection Equity Switzerland L      1610.32         1610.32
# 15                      CSA Mid Yield Bonds CHF      1449.42         1449.42
# 16                                 BVG Wachstum     1'524.16        1'518.08
# 17                IST Oblig. Ausland Hedged CHF      1179.47         1177.81
# 18                  IST Governo Bond Hedged CHF      1411.43         1410.01
# 19               OBLIGATIONEN AUSLAND FW HEDGED       124.07          124.07
# 20                      CSA 2 Mixta-BVG 25 Plus      1246.28         1246.28
# 21                            Immobilien Europa       166017          166017
# 22                       Wohnimmobilien Schweiz      1352.13         1352.13
# 23                     CSA Mixta-BVG Index 45 I      1362.15         1358.48
# 24                    CSA Global Bonds Hedged L       1170.5          1170.5
# 25                                 CONVERTIBLES       102.84          102.84
# 26                            BVG 3 PORTFOLIO10       190.32          190.32
# 27                            BVG 3 PORTFOLIO25       180.25          180.25
# 28                           BVG 3 PORTFOLIO 45       209.51          209.51
# 29                                BVG 3 OEKO 45        147.3           147.3
# ..                                          ...          ...             ...
# 390                  IST America Small Mid Caps      1986.22         1976.32
# 391            IST Wandelobl. Global Hedged CHF       152.03          151.73
# 392                    CSA Equity Switzerland L      2346.86         2346.86
# 393                           IST America Index      1667.92         1663.92
# 394                            IST Europe Index        584.5          579.96
# 395                           IST Pacific Index       321.39          320.23
# 399                      Awi Immobilien Schweiz      1081.42         1081.42
# 400               Nachhaltig Immobilien Schweiz       1256.8          1256.8
# 401                       OBLIGATIONEN EURO TOP         65.3            65.3
# 402                     OBLIGATIONEN DOLLAR TOP        74.91           74.91
# 403                            OBLIGATIONEN YEN        60.35           60.35
# 404                              Aktien Schweiz         1988            1988
# 405                      AVANT BVG PORTFOLIO 25       152.67          152.67
# 414                      CSA Mixta-BVG Defensiv      1667.11         1667.11
# 416                           BVG-Mix 40 Plus I     1'897.63        1'897.63
# 417                        Obligationen Schweiz     1'476.92        1'476.92
# 418                              Aktien Schweiz     4'656.99        4'656.99
# 419                          CSA 2 Mixta-BVG 25      1455.27         1455.27
# 420                          CSA 2 Mixta-BVG 35       1392.7          1392.7
# 421                          CSA 2 Mixta-BVG 45      1409.33         1409.33
# 422                             CSA Swiss Index      1624.12          1623.8
# 423                          CSA Mixta-BVG Maxi      1532.31         1532.31
# 424                          AWi BVG 25 andante      1486.55         1486.55
# 425                           AWi BVG 45 vivace      1539.44         1539.44
# 426                 AWi Obligationen Inland CHF      1139.02         1139.02
# 432                      OBLIGATIONEN EURO PLUS        69.77           69.77
# 433                    OBLIGATIONEN DOLLAR PLUS        89.97           89.97
# 434                             IST Globe Index      2567.89         2558.15
# 435                     CHF-Obligationen Inland         1437            1437
# 436            Nachhaltig Oblig. Intern. ex CHF         1045            1045
#
#     AUFGEL_ERTRAG  EINGABESCHLUSS ABSCHLUSSTAG      VALUTA AENDERUNGSDAT
# 0               0      15:00 Uhr    2016-10-13  2016-10-17    2016-10-14
# 1               0        12:00 h    2016-10-12  2016-10-17    2016-10-14
# 2            1.32        monthly    2016-08-31  2016-08-25    2016-10-14
# 3           12.58       10.00 Uhr   2016-10-12  2016-10-14    2016-10-13
# 4           -3.03       10.00 Uhr   2016-10-12  2016-10-14    2016-10-13
# 5               0  Do/jeudi 17:00   2016-10-07  2016-10-13    2016-10-11
# 6           -3.17      12:00 Uhr    2016-10-12  2016-10-17    2016-10-14
# 7               0      14:30 Uhr    2016-10-13  2016-10-17    2016-10-14
# 8            -1.5      15:30 Uhr    2016-10-13  2016-10-17    2016-10-14
# 9               0               -   2016-09-30  2016-10-01    2016-10-03
# 10              0               -   2016-09-30  2016-10-01    2016-10-03
# 11              0       14.30 Uhr   2016-10-12  2016-10-17    2016-10-13
# 12              0      10:30 Uhr    2016-10-12  2016-10-15    2016-10-14
# 13              0      10:30 Uhr    2016-10-12  2016-10-15    2016-10-14
# 14           0.46      10:30 Uhr    2016-10-12  2016-10-15    2016-10-14
# 15              0      15:30 Uhr    2016-10-13  2016-10-17    2016-10-14
# 16              0        12:00 h    2016-10-12  2016-10-17    2016-10-14
# 17       -0.11318           14:00   2016-10-13         NaN    2016-10-14
# 18       -0.11787           14:00   2016-10-13         NaN    2016-10-14
# 19           n.a.       14:00 Uhr   2016-10-13  2016-10-18    2016-10-14
# 20          -0.31      12:00 Uhr    2016-10-13  2016-10-17    2016-10-14
# 21         -2.465         14.00 h   2016-09-30  2016-09-30    2016-10-07
# 22          15.31               -   2016-09-30  2016-09-30    2016-10-03
# 23          -1.62      12:00 Uhr    2016-10-12  2016-10-17    2016-10-14
# 24          -1.25      15:30 Uhr    2016-10-13  2016-10-17    2016-10-14
# 25           n.a.       14:00 Uhr   2016-10-13  2016-10-18    2016-10-14
# 26           n.a.      12:30 Uhr    2016-10-13  2016-10-18    2016-10-14
# 27           n.a.      12:30 Uhr    2016-10-13  2016-10-18    2016-10-14
# 28           n.a.      12:30 Uhr    2016-10-13  2016-10-18    2016-10-14
# 29           n.a.      12:30 Uhr    2016-10-13  2016-10-18    2016-10-14
# ..            ...             ...          ...         ...           ...
# 390       -1.1085           14:00   2017-03-03         NaN    2017-03-06
# 391      -0.20867           14:00   2017-03-03         NaN    2017-03-06
# 392         -0.32      15:30 Uhr    2017-03-03  2017-03-07    2017-03-06
# 393      -1.01023           14:00   2017-03-03         NaN    2017-03-06
# 394      -0.35923           14:00   2017-03-03         NaN    2017-03-06
# 395      -0.20126           14:00   2017-03-03         NaN    2017-03-06
# 399           NaN      12:00 Uhr    2016-06-30  2016-06-30    2017-03-06
# 400             0       10.00 Uhr   2017-03-03  2017-03-07    2017-03-06
# 401          n.a.       14:00 Uhr   2017-03-03  2017-03-08    2017-03-06
# 402          n.a.       14:00 Uhr   2017-03-03  2017-03-08    2017-03-06
# 403          n.a.       14:00 Uhr   2017-03-03  2017-03-08    2017-03-06
# 404         -2.01       10.00 Uhr   2017-03-03  2017-03-07    2017-03-06
# 405          n.a.      12:30 Uhr    2017-03-03  2017-03-08    2017-03-06
# 414         -5.47      12:00 Uhr    2017-03-03  2017-03-07    2017-03-06
# 416          -0.6       12:00 Uhr   2017-03-03  2017-03-07    2017-03-06
# 417             0       12:00 Uhr   2017-03-03  2017-03-07    2017-03-06
# 418             0       12:00 Uhr   2017-03-03  2017-03-07    2017-03-06
# 419         -0.87      12:00 Uhr    2017-03-03  2017-03-07    2017-03-06
# 420         -0.82      12:00 Uhr    2017-03-03  2017-03-07    2017-03-06
# 421         -1.03      12:00 Uhr    2017-03-03  2017-03-07    2017-03-06
# 422          -1.8       13:00 Uhr   2017-03-03  2017-03-07    2017-03-06
# 423         -6.36      12:00 Uhr    2017-03-03  2017-03-07    2017-03-06
# 424         -0.46      12:00 Uhr    2017-03-02  2017-03-08    2017-03-06
# 425          -0.2      12:00 Uhr    2017-03-02  2017-03-08    2017-03-06
# 426          -0.2      12:00 Uhr    2017-03-03  2017-03-08    2017-03-06
# 432          n.a.       14:00 Uhr   2017-03-03  2017-03-08    2017-03-06
# 433          n.a.       14:00 Uhr   2017-03-03  2017-03-08    2017-03-06
# 434      -1.53545           14:00   2017-03-03         NaN    2017-03-06
# 435         22.07       10.00 Uhr   2017-03-03  2017-03-07    2017-03-06
# 436         25.77       10.00 Uhr   2017-03-03  2017-03-07    2017-03-06
#
# [29011 rows x 12 columns]

# %%
dflist = []
for fname in fnames:
    dflist.append(get_itd(p.pfadSIX + fname))  
df = concat(dflist).drop_duplicates()
df.sort_index(inplace=True)
df.Volume = df.Volume.map(lambda x: None if x == 0 else x)
funds = df.Name.drop_duplicates().tolist()
#funds = df.index.get_level_values(0).drop_duplicates().tolist()
df.info()
spi = funds[1]
funds, spi

# %%
faktoren = {}
for fund in funds:
    startwert = df[df.Name == fund].Price[0]
    print(fund, startwert)
    faktoren[fund] = 1 / startwert * 100

df['Faktor'] = df.Name.map(lambda x:faktoren[x])
df['PriceAdj'] = df.Price * df.Faktor

# %%
df[df.Name == funds[0]]

# %%
for fund in funds:
    df[df.Name == fund].PriceAdj.plot()
